# %%
#1.kutuphaneler
import pandas as pd
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor

# %%
dizin_yolu = os.getcwd()

dizin = dizin_yolu.replace('\\','/')
path = f'{dizin}/MELBOURNE_HOUSE_PRICES_LESS.csv'

df = pd.read_csv(path)

# %%
df
# Out:
#                  Suburb           Address  Rooms Type      Price Method  \
# 0            Abbotsford     49 Lithgow St      3    h  1490000.0      S
# 1            Abbotsford     59A Turner St      3    h  1220000.0      S
# 2            Abbotsford     119B Yarra St      3    h  1420000.0      S
# 3            Aberfeldie        68 Vida St      3    h  1515000.0      S
# 4          Airport West  92 Clydesdale Rd      2    h   670000.0      S
# ...                 ...               ...    ...  ...        ...    ...
# 63018     Roxburgh Park         3 Carr Pl      3    h   566000.0      S
# 63019     Roxburgh Park       9 Parker Ct      3    h   500000.0      S
# 63020     Roxburgh Park    5 Parkinson Wy      3    h   545000.0      S
# 63021        Thomastown    3/1 Travers St      3    u        NaN     PI
# 63022  Williams Landing       1 Diadem Wy      4    h        NaN     SP
#
#         SellerG        Date  Postcode             Regionname  Propertycount  \
# 0        Jellis   1/04/2017      3067  Northern Metropolitan           4019
# 1      Marshall   1/04/2017      3067  Northern Metropolitan           4019
# 2        Nelson   1/04/2017      3067  Northern Metropolitan           4019
# 3         Barry   1/04/2017      3040   Western Metropolitan           1543
# 4        Nelson   1/04/2017      3042   Western Metropolitan           3464
# ...         ...         ...       ...                    ...            ...
# 63018     Raine  31/03/2018      3064  Northern Metropolitan           5833
# 63019     Raine  31/03/2018      3064  Northern Metropolitan           5833
# 63020     Raine  31/03/2018      3064  Northern Metropolitan           5833
# 63021     Barry  31/03/2018      3074  Northern Metropolitan           7955
# 63022    Aussie  31/03/2018      3027   Western Metropolitan           1999
#
#        Distance                 CouncilArea
# 0           3.0          Yarra City Council
# 1           3.0          Yarra City Council
# 2           3.0          Yarra City Council
# 3           7.5  Moonee Valley City Council
# 4          10.4  Moonee Valley City Council
# ...         ...                         ...
# 63018      20.6           Hume City Council
# 63019      20.6           Hume City Council
# 63020      20.6           Hume City Council
# 63021      15.3     Whittlesea City Council
# 63022      17.6        Wyndham City Council
#
# [63023 rows x 13 columns]

# %%
# Tarih sütununu tarih nesnelerine dönüştürme
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y')

# Tarih sütunundan yıl, ay ve gün özelliklerini çıkarma
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month
df['Day'] = df['Date'].dt.day

# %%
addres = df["Address"]
addres = df['Address'].str.split(' ', expand=True)

df['No'] = addres[0]
df['Street'] = addres[1]
df['type_of_address'] = addres[2]
df = df.drop(columns=['Date',"Address"])
df
# Out:
#                  Suburb  Rooms Type      Price Method   SellerG  Postcode  \
# 0            Abbotsford      3    h  1490000.0      S    Jellis      3067
# 1            Abbotsford      3    h  1220000.0      S  Marshall      3067
# 2            Abbotsford      3    h  1420000.0      S    Nelson      3067
# 3            Aberfeldie      3    h  1515000.0      S     Barry      3040
# 4          Airport West      2    h   670000.0      S    Nelson      3042
# ...                 ...    ...  ...        ...    ...       ...       ...
# 63018     Roxburgh Park      3    h   566000.0      S     Raine      3064
# 63019     Roxburgh Park      3    h   500000.0      S     Raine      3064
# 63020     Roxburgh Park      3    h   545000.0      S     Raine      3064
# 63021        Thomastown      3    u        NaN     PI     Barry      3074
# 63022  Williams Landing      4    h        NaN     SP    Aussie      3027
#
#                   Regionname  Propertycount  Distance  \
# 0      Northern Metropolitan           4019       3.0
# 1      Northern Metropolitan           4019       3.0
# 2      Northern Metropolitan           4019       3.0
# 3       Western Metropolitan           1543       7.5
# 4       Western Metropolitan           3464      10.4
# ...                      ...            ...       ...
# 63018  Northern Metropolitan           5833      20.6
# 63019  Northern Metropolitan           5833      20.6
# 63020  Northern Metropolitan           5833      20.6
# 63021  Northern Metropolitan           7955      15.3
# 63022   Western Metropolitan           1999      17.6
#
#                       CouncilArea  Year  Month  Day    No      Street  \
# 0              Yarra City Council  2017      4    1    49     Lithgow
# 1              Yarra City Council  2017      4    1   59A      Turner
# 2              Yarra City Council  2017      4    1  119B       Yarra
# 3      Moonee Valley City Council  2017      4    1    68        Vida
# 4      Moonee Valley City Council  2017      4    1    92  Clydesdale
# ...                           ...   ...    ...  ...   ...         ...
# 63018           Hume City Council  2018      3   31     3        Carr
# 63019           Hume City Council  2018      3   31     9      Parker
# 63020           Hume City Council  2018      3   31     5   Parkinson
# 63021     Whittlesea City Council  2018      3   31   3/1     Travers
# 63022        Wyndham City Council  2018      3   31     1      Diadem
#
#       type_of_address
# 0                  St
# 1                  St
# 2                  St
# 3                  St
# 4                  Rd
# ...               ...
# 63018              Pl
# 63019              Ct
# 63020              Wy
# 63021              St
# 63022              Wy
#
# [63023 rows x 17 columns]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Suburp_encoded'] = label_encoder.fit_transform(df['Suburb'])
df['Type_encoded'] = label_encoder.fit_transform(df['Type'])
df['Method_encoded'] = label_encoder.fit_transform(df['Method'])
df['SellerG_encoded'] = label_encoder.fit_transform(df['SellerG'])
df['Regionname_encoded'] = label_encoder.fit_transform(df['Regionname'])
df['CouncilArea_encoded'] = label_encoder.fit_transform(df['CouncilArea'])
df['Street_encoded'] = label_encoder.fit_transform(df['Street'])
df['type_of_address_encoded'] = label_encoder.fit_transform(df['type_of_address'])

# %%
df = df[df['No'].notna()]
df
# Out:
#                  Suburb  Rooms Type      Price Method   SellerG  Postcode  \
# 0            Abbotsford      3    h  1490000.0      S    Jellis      3067
# 1            Abbotsford      3    h  1220000.0      S  Marshall      3067
# 2            Abbotsford      3    h  1420000.0      S    Nelson      3067
# 3            Aberfeldie      3    h  1515000.0      S     Barry      3040
# 4          Airport West      2    h   670000.0      S    Nelson      3042
# ...                 ...    ...  ...        ...    ...       ...       ...
# 63018     Roxburgh Park      3    h   566000.0      S     Raine      3064
# 63019     Roxburgh Park      3    h   500000.0      S     Raine      3064
# 63020     Roxburgh Park      3    h   545000.0      S     Raine      3064
# 63021        Thomastown      3    u        NaN     PI     Barry      3074
# 63022  Williams Landing      4    h        NaN     SP    Aussie      3027
#
#                   Regionname  Propertycount  Distance  ...      Street  \
# 0      Northern Metropolitan           4019       3.0  ...     Lithgow
# 1      Northern Metropolitan           4019       3.0  ...      Turner
# 2      Northern Metropolitan           4019       3.0  ...       Yarra
# 3       Western Metropolitan           1543       7.5  ...        Vida
# 4       Western Metropolitan           3464      10.4  ...  Clydesdale
# ...                      ...            ...       ...  ...         ...
# 63018  Northern Metropolitan           5833      20.6  ...        Carr
# 63019  Northern Metropolitan           5833      20.6  ...      Parker
# 63020  Northern Metropolitan           5833      20.6  ...   Parkinson
# 63021  Northern Metropolitan           7955      15.3  ...     Travers
# 63022   Western Metropolitan           1999      17.6  ...      Diadem
#
#        type_of_address  Suburp_encoded  Type_encoded Method_encoded  \
# 0                   St               0             0              2
# 1                   St               0             0              2
# 2                   St               0             0              2
# 3                   St               1             0              2
# 4                   Rd               2             0              2
# ...                ...             ...           ...            ...
# 63018               Pl             295             0              2
# 63019               Ct             295             0              2
# 63020               Wy             295             0              2
# 63021               St             332             2              0
# 63022               Wy             364             0              5
#
#       SellerG_encoded Regionname_encoded  CouncilArea_encoded  Street_encoded  \
# 0                 198                  2                   32            5600
# 1                 255                  2                   32            9310
# 2                 286                  2                   32           10105
# 3                  28                  6                   22            9467
# 4                 286                  6                   22            1986
# ...               ...                ...                  ...             ...
# 63018             344                  2                   11            1643
# 63019             344                  2                   11            7250
# 63020             344                  2                   11            7257
# 63021              28                  2                   30            9217
# 63022              23                  6                   31            2608
#
#        type_of_address_encoded
# 0                          214
# 1                          214
# 2                          214
# 3                          214
# 4                          191
# ...                        ...
# 63018                      175
# 63019                       63
# 63020                      245
# 63021                      214
# 63022                      245
#
# [63023 rows x 25 columns]

# %%
no_column = df['No'].values
no_cleaned = [value.replace('/', '').replace('A', '').replace('B', '').replace('C', '') for value in no_column]

# Yeni bir "No_clean" sütunu oluşturun
df['No_clean'] = no_cleaned

df = df[df['Price'].notna()]
df['No_clean'] = pd.to_numeric(df['No_clean'], errors='coerce', downcast='integer')
df = df[df['No_clean'].notna()]
# Out:
# C:\Users\enes_\AppData\Local\Temp\ipykernel_4736\376194645.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['No_clean'] = pd.to_numeric(df['No_clean'], errors='coerce', downcast='integer')

# %%
df = df.drop(columns=['Suburb','Type','Method','SellerG','Regionname','CouncilArea','Street','type_of_address','No'])
df
y = df['Price']
X = df.drop("Price", axis=1)  # Özellikler
print(df.dtypes)
# Out:
# Rooms                        int64
# Price                      float64
# Postcode                     int64
# Propertycount                int64
# Distance                   float64
# Year                         int64
# Month                        int64
# Day                          int64
# Suburp_encoded               int32
# Type_encoded                 int32
# Method_encoded               int32
# SellerG_encoded              int32
# Regionname_encoded           int32
# CouncilArea_encoded          int32
# Street_encoded               int32
# type_of_address_encoded      int32
# No_clean                   float64
# dtype: object

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
print(y)
#Burada XGBoost modeli oluşturuyoruz, buradaki paramatreler değiştilerek belki daha başarılı sonuçlar elde edilebilir.
model = XGBRegressor(n_estimators=100, max_depth=7, random_state=42)
model.fit(X_train, y_train)
# Out:
# 0        1490000.0
# 1        1220000.0
# 2        1420000.0
# 3        1515000.0
# 4         670000.0
#            ...
# 63016     347700.0
# 63017     808000.0
# 63018     566000.0
# 63019     500000.0
# 63020     545000.0
# Name: Price, Length: 47356, dtype: float64
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=7, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=42, ...)

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([1255380.2, 1095769.1,  840474.9, ...,  738522.3,  823090.5,
#         741817.7], dtype=float32)

# %%
from sklearn.metrics import r2_score
r2 = r2_score(y_test, y_pred)
print(f"R-squared Score: {r2:.2f}")
# Out:
# R-squared Score: 0.75
